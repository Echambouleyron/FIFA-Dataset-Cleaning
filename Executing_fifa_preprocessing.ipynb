# %%
from cleaning_fifa_data_module import *

# %%
pre_procesamiento = fifa_data()

# %%
x = pre_procesamiento.load_drop_data('data.csv')
# Out:
# C:\Users\Administrador\Anaconda3\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
pre_procesamiento.clean(x)
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      192985        K. De Bruyne   27     Belgium       91         92
# 4      183277           E. Hazard   27     Belgium       91         91
# ...       ...                 ...  ...         ...      ...        ...
# 14738  238813        J. Lundstram   19     England       47         65
# 14739  243165  N. Christoffersson   19      Sweden       47         63
# 14740  241638           B. Worman   16     England       47         67
# 14741  246268      D. Walker-Rice   17     England       47         66
# 14742  246269           G. Nugent   16     England       46         66
#
#                       Club   Value  Wage  Special  ... GKDiving  GKHandling  \
# ...

# %%
df = pre_procesamiento.limpiar(x)
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      192985        K. De Bruyne   27     Belgium       91         92
# 4      183277           E. Hazard   27     Belgium       91         91
# ...       ...                 ...  ...         ...      ...        ...
# 14738  238813        J. Lundstram   19     England       47         65
# 14739  243165  N. Christoffersson   19      Sweden       47         63
# 14740  241638           B. Worman   16     England       47         67
# 14741  246268      D. Walker-Rice   17     England       47         66
# 14742  246269           G. Nugent   16     England       46         66
#
#                       Club       Value    Wage  Special  ... GKDiving  \
# ...
